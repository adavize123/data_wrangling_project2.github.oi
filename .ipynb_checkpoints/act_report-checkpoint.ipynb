# %% [markdown]
# ## Analyzing and Visualizing Data
#
# ## Analyzing(Observation and finding)
#
# #### In this section, analyze and visualize your wrangled data. three insight are produced and  one visualization
# ### Insights: The following are below insights deduced from the wrangling process
# #### 1. I really think this Dataframe is the must important amonge the dataset and also the main dataset
# ######  The df_archive is the main dataset, and from the observation every information revolve around the the main dataset df_archive
# #### 2. The tweet_data_clean contain an additional data of the main dataset( df_archive_clean)
# ######  This is the tweeet_json.txt file that is gotten from the twitter API  which contain two columns ( retweet_count and favourite_count) that belongs to the archive table
# #### 3. the retweet in the dataset is much more than the main tweet or the originl tweet
# ###### From the observation so far retweet are more than the main tweet
# ## Visualizing Data
# ![image.png](attachment:image.png)
# ###### 1. my visualization process was done by plotting a histograme of retweet_count and favourite_count by comparing the two to see which of the tweet is more than the other in due time. The chat shows that the favourite have are more likes count than the retweet using matplotlib inline
# ###### 2. This plot show number of rating of dog (dog_rating) on the point that has valued (1750) favourite count and within 10,000 to 20,000 like and have really been effective enough to determine the structure of the chart on getting the actual information from the plot.
# ###### 3. The plot have shown the area at which like are much which are as follow
# 1. favourite_count at the highest of 1750
# 2. retweet_count betweet the 10,000 and 20,000
